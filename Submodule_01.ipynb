# %% [markdown]
# # MDIBL Transcriptome Assembly Learning Module
# # Notebook 1: Setup

# %% [markdown]
# ## Overview
#
# This notebook is designed to configure your virtual machine (VM) to have the proper tools and data in place to run the transcriptome assembly training module.

# %% [markdown]
# ## Learning Objectives
#
# 1. **Understand and utilize shell commands within Jupyter Notebooks:**  The notebook explicitly teaches the difference between `!` and `%` prefixes for executing shell commands, and how to navigate directories using `cd` and `pwd`.
#
# 2. **Set up the necessary software:** Students will install and configure essential tools including:
#     * Java (a prerequisite for Nextflow).
#     * Miniforge (a package manager for bioinformatics tools).
#     *  `sra-tools`, `perl-dbd-sqlite`, and `perl-dbi` (specific bioinformatics packages).
#     * Nextflow (a workflow management system).
#     *  `gsutil` (for interacting with Google Cloud Storage).
#
# 3. **Download and organize necessary data:** Students will download the TransPi transcriptome assembly software and its associated resources (databases, scripts, configuration files) from a Google Cloud Storage bucket.  This includes understanding the directory structure and file organization.
#
# 4. **Manage file permissions:** Students will use the `chmod` command to set executable permissions for the necessary files and directories within the TransPi software.
#
# 5. **Navigate file paths:** The notebook provides examples and explanations for using relative file paths (e.g., `./`, `../`) within shell commands.

# %% [markdown]
# ## Prerequisites
#
# * **Operating System:** A Linux-based system is assumed (commands like `apt`, `uname` are used).  The specific distribution isn't specified but a Debian-based system is likely.
# * **Shell Access:**  The ability to execute shell commands from within the Jupyter Notebook environment (using `!` and `%`).
# * **Java Development Kit (JDK):**  Required for Nextflow.
# * **Miniforge** A package manager for installing bioinformatics tools.
# * **`gsutil`:** The Google Cloud Storage command-line tool. This is crucial for downloading data from Google Cloud Storage.

# %% [markdown]
# ## Get Started

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <i class="fa fa-hand-paper-o" aria-hidden="true"></i>
#     <b>Note: </b>  ! and % in code cells
# </div>
#
# >You may notice that many of the lines in the code cells begin with one of these symbols: `!` or `%`. They both allow you (the user) to run shell commands in the code cells of a Juypter notebook. They do, however, operate slightly differently:
# >- The `!` executes the command and then immediately terminates.
# >- The `%` executes the command and has a lasting effect.
#
# <div class="alert alert-block alert-warning">
#     <i class="fa fa-pencil" aria-hidden="true"></i>
#     <b>Example:</b>
# </div>
#
# >Take this example code snippet: *Imagine that you are currently in the directory named* `original-directory`.
# >```python
# !cd different-directory/
# >```
# >After this line executes, you will still be in the directory named `original-directory`.
# >
# >**Vs.**
# >```python
# %cd different-directory/
# >```
# >After this line executes, you will now be in the directory `different-directory`.

# %% [markdown]
# ## Time to begin!
#
# **Step 1:** To start, make sure that you are in the right starting place with a `cd`.
# > `pwd` prints our current local working directory. Make sure the output from the command is: `/home/jupyter`

# %%
# %cd /home/
# Out:
# [Errno 2] No such file or directory: '/home/jupyter'
# /home/ec2-user/SageMaker/Transcriptome-Assembly-Refinement-and-Applications/AWS

# %%
! pwd
# Out:
# /home/ec2-user/SageMaker/Transcriptome-Assembly-Refinement-and-Applications/AWS

# %% [markdown]
# **Step 2:** Now, update the system and install Java (which is needed for Nextflow to run).

# %%
! sudo apt update
! sudo apt-get install default-jdk -y
! java -version

# %% [markdown]
# **Step 3:** Install Miniforge (a package manager), which is needed to support the information held within the TransPi databases.

# %%
! curl -L -O https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-$(uname)-$(uname -m).sh
! bash Miniforge3-$(uname)-$(uname -m).sh -b -p $HOME/miniforge

# %% [markdown]
# Next, add it to the path.

# %%
import os
os.environ["PATH"] += os.pathsep + os.environ["HOME"]+"/miniforge/bin"

# %% [markdown]
# Next, using Miniforge and bioconda, install the tools that will be used in this tutorial.

# %%
! mamba install -c bioconda sra-tools perl-dbd-sqlite perl-dbi -y

# %% [markdown]
# **Step 4:** Now, install Nextflow, make it executable, and update it.

# %%
! curl https://get.nextflow.io | bash
! chmod +x nextflow
! ./nextflow self-update

# %% [markdown]
# **Step 5:** Time to get TransPi.
# >The original version of TransPi is available on GitHub, however, we have made a variety of alterations to the program and will be using the updated version in the following modules.

# %%
! aws s3 cp --recursive s3://nigms-sandbox/nosi-inbremaine-storage/TransPi ./TransPi
# Out:
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/Dockerfile to TransPi/Dockerfile
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/busco_comparison.R to TransPi/bin/busco_comparison.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/TransPi_Report_Ind.Rmd to TransPi/bin/TransPi_Report_Ind.Rmd
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/custom_uniprot_hits.R to TransPi/bin/custom_uniprot_hits.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/LICENSE to TransPi/LICENSE
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/GO_plots.R to TransPi/bin/GO_plots.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/SOS_busco.py to TransPi/bin/SOS_busco.py
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/get_busco_val.sh to TransPi/bin/get_busco_val.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/Makefile to TransPi/docs/Makefile
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/get_sizes.sh to TransPi/bin/get_sizes.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/get_readqual.sh to TransPi/bin/get_readqual.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/README.md to TransPi/README.md
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/description.adoc to TransPi/docs/description.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/addAnnotation.py to TransPi/bin/addAnnotation.py
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/install.adoc to TransPi/docs/install.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/extra.adoc to TransPi/docs/extra.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/heatmap_busco.R to TransPi/bin/heatmap_busco.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/TransPi.nf to TransPi/TransPi.nf
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/index.adoc to TransPi/docs/index.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/run.adoc to TransPi/docs/run.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/get_readstats.sh to TransPi/bin/get_readstats.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/issues.adoc to TransPi/docs/issues.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/options.adoc to TransPi/docs/options.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/results.adoc to TransPi/docs/results.adoc
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/remove_failed.sh to TransPi/remove_failed.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/bin/len.py to TransPi/bin/len.py
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/nextflow.config to TransPi/nextflow.config
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/conf/test.config to TransPi/conf/test.config
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/conf/busV4list.txt to TransPi/conf/busV4list.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/conf/uni_tax.txt to TransPi/conf/uni_tax.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/index.html to TransPi/docs/index.html
# download: s3://nigms-sandbox/nosi-inbremaine-storage/TransPi/docs/examples.adoc to TransPi/docs/examples.adoc

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <i class="fa fa-hand-paper-o" aria-hidden="true"></i>
#     <b>Note: </b>  aws s3
# </div>
#
# >`aws s3` is a tool allows you to interact with Amazon S3 through the command line.

# %% [markdown]
# **Step 6:** Now copy over all of the additional resources needed for TransPi to run. This may take a few minutes.
# > Within the resources directory, 5 sub-directories are needed: `/bin`, `/conf`, `/DBs`, `/seq2`, and `trans`.
# > - In the **`/bin`** directory, there are a set of programs that get called by various processes within the TransPi workflow. One example `GO_plots.R` is an R script that creates plots showing gene ontology of the built transcriptome.
# > - In the **`/conf`** directory, there are 3 files, but we will only be using `uni_tax.txt` which contains the UniProt taxonomy codes.
# > - In the **`/DBs`** directory, there are 3 sub-directories containing 3 databases that TransPi needs:
# >    - **`/hmmerdb`**  contains the `Pfam_A.hmm` file which is a database of protein families. This database is used to annotate the transcriptome that is built using probabilities built from Hidden Markov Models.
# >    - **`/sqlite_db`** contains the necessary files and database to run DIAMOND, a program that swiftly aligns the built transcriptome to a database of known proteins.
# >    - **`/uniprot_db`:** contains a different database to run DIAMOND and to run TransDecoder, a program that identifies coding regions.

# %%
! aws s3 cp --recursive s3://nigms-sandbox/nosi-inbremaine-storage/resources ./resources
# Out:
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/hmmerdb/.lastrun.txt to resources/DBs/hmmerdb/.lastrun.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/.lastrun.txt to resources/DBs/sqlite_db/.lastrun.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/.gitmodules to resources/DBs/sqlite_db/Trinotate_build_scripts/.gitmodules
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/LICENSE.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/LICENSE.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/Changelog.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/Changelog.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/DelimParser.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/DelimParser.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/EMBL_parser.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/EMBL_parser.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Fasta_reader.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Fasta_reader.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GFF3_utils.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GFF3_utils.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GO_DAG.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GO_DAG.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate-v3.2.2.tar.gz to resources/DBs/sqlite_db/Trinotate-v3.2.2.tar.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GTF_utils.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GTF_utils.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GTF.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/GTF.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/IniReader.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/IniReader.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Gene_obj_indexer.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Gene_obj_indexer.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Longest_orf.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Longest_orf.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Overlap_piler.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Overlap_piler.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Gene_obj.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Gene_obj.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Pipeliner.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Pipeliner.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Nuc_translator.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Nuc_translator.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Process_cmd.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Process_cmd.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Sqlite_connect.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Sqlite_connect.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/TiedHash.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/TiedHash.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Trinotate.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/Trinotate.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/TextCache.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/TextCache.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/obo/notes to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/obo/notes
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/obo/goslim_generic.obo.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/obo/goslim_generic.obo.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/obo/go-basic.obo.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/obo/go-basic.obo.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/test_GO_DAG.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/PerlLib/test_GO_DAG.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/README.md to resources/DBs/sqlite_db/Trinotate_build_scripts/README.md
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/README.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/README.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/Trinotate to resources/DBs/sqlite_db/Trinotate_build_scripts/Trinotate
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb.conf/lighttpd.conf.template to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb.conf/lighttpd.conf.template
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/DE_sample_pair.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/DE_sample_pair.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/HeatmapNav.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/HeatmapNav.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/BasePlot.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/BasePlot.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Barplot.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Barplot.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/GenomeBrowser.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/GenomeBrowser.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Heatmap.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Heatmap.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Line.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Line.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Piechart.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Piechart.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/PlotOnLoader.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/PlotOnLoader.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Scatter2D.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Scatter2D.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Sunburst.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/Sunburst.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvas.text.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvas.text.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/app.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/app.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/Ext.ux.SearchWindow.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/Ext.ux.SearchWindow.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvas.text.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvas.text.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvas2png.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvas2png.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.gif to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.gif
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.doc.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.doc.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.public.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.public.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/color-field.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/color-field.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/canvasXpress.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/date.format.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/date.format.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/date.format.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/date.format.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/excanvas.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/excanvas.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/ext-canvasXpress.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/ext-canvasXpress.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/extext.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/extext.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/flash10canvas.swf to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/flash10canvas.swf
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/flash9canvas.swf to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/flash9canvas.swf
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/gentilis_regular.typeface.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/gentilis_regular.typeface.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/flashcanvas.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/flashcanvas.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/helvetiker_regular.typeface.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/helvetiker_regular.typeface.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/sprintf.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/sprintf.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/sprintf.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/sprintf.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Barplot.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Barplot.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_GenomeBrowser.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_GenomeBrowser.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/tableXpress.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/js/tableXpress.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Lineplot.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Lineplot.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Piechart.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Piechart.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Heatmap.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Heatmap.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Scatter2D.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Scatter2D.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Sunburst.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_Sunburst.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_heatmap.html to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_heatmap.html
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_isaac.html to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_isaac.html
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_scatter2D.html to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_scatter2D.html
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_line.html to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/CanvasXpress/tests/test_line.html
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/__stub.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/__stub.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/feature_report.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/feature_report.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/DEWebCommon.pm to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/PerlLib/DEWebCommon.pm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/env.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/env.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/get_feature_loc.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/get_feature_loc.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/DE_sample_pair.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/DE_sample_pair.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/dashboard-footer.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/dashboard-footer.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/DE.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/DE.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/HeatmapNav.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/HeatmapNav.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/dashboard-header.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/dashboard-header.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_footer.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_footer.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_expression.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_expression.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/footer.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/footer.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_transcript.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_transcript.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_header.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/feature_report_header.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/go.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/go.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/gene_search.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/gene_search.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate.sqlite to resources/DBs/sqlite_db/Trinotate.sqlite
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/header.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/header.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/keyword_search.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/keyword_search.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/overview.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/overview.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/pfam.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/pfam.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/topsp.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/topsp.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/taxonomy_best_hit.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/taxonomy_best_hit.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/topnav.tabless.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/topnav.tabless.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/index.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/index.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/Ext.ux.SearchWindow.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/Ext.ux.SearchWindow.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvas.text.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvas.text.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/topnav.tmpl to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/html/topnav.tmpl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvas2png.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvas2png.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvas.text.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvas.text.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.gif to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.gif
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.doc.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.doc.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/app.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/app.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/color-field.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/color-field.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.public.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.public.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/canvasXpress.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/date.format.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/date.format.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/date.format.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/date.format.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/excanvas.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/excanvas.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/flash10canvas.swf to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/flash10canvas.swf
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/ext-canvasXpress.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/ext-canvasXpress.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/flash9canvas.swf to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/flash9canvas.swf
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/flashcanvas.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/flashcanvas.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/extext.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/extext.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/helvetiker_regular.typeface.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/helvetiker_regular.typeface.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/sprintf.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/sprintf.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/sprintf.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/sprintf.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/keyword_search.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/keyword_search.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/gentilis_regular.typeface.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/gentilis_regular.typeface.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/tableXpress.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js/tableXpress.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js2/datadumper.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/js2/datadumper.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/test.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/test.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/transcript_cluster_viewer.cgi to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/cgi-bin/transcript_cluster_viewer.cgi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/common.css to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/common.css
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/dashboard.css to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/dashboard.css
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/bootstrap.min.css to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/bootstrap.min.css
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/canvasXpress.css to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/css/canvasXpress.css
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/excanvas.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/excanvas.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/ie10-viewport-bug-workaround.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/ie10-viewport-bug-workaround.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/bootstrap.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/bootstrap.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/canvasXpress.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/canvasXpress.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/trinotate-web.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/trinotate-web.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/Build_Trinotate_Boilerplate_SQLite_db.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/Build_Trinotate_Boilerplate_SQLite_db.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/jquery.min.js to resources/DBs/sqlite_db/Trinotate_build_scripts/TrinotateWeb/js/jquery.min.js
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/cleanMe.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/cleanMe.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/EMBL_swissprot_parser.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/EMBL_swissprot_parser.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/EMBL_dat_to_Trinotate_sqlite_resourceDB.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/EMBL_dat_to_Trinotate_sqlite_resourceDB.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/PFAM_dat_parser.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/PFAM_dat_parser.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/obo_tab_to_sqlite_db.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/obo_tab_to_sqlite_db.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/PFAMtoGoParser.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/PFAMtoGoParser.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/obo_to_tab.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/obo_to_tab.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/print.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/print.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/init_Trinotate_sqlite_db.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/admin/util/init_Trinotate_sqlite_db.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/autoTrinotate.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/autoTrinotate.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/conf.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/conf.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/conf.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/conf.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/cleanme.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/cleanme.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/myTrinity.fasta.gene_to_trans_map.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/myTrinity.fasta.gene_to_trans_map.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/mini_sprot.pep.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/mini_sprot.pep.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/runMe.sh to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/runMe.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/myTrinity.fasta.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/auto/testing/myTrinity.fasta.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/notes to resources/DBs/sqlite_db/Trinotate_build_scripts/notes
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/resources/eggnog/3.0/notes to resources/DBs/sqlite_db/Trinotate_build_scripts/resources/eggnog/3.0/notes
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/resources/eggnog/3.0/fun.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/resources/eggnog/3.0/fun.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/run_TrinotateWebserver.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/run_TrinotateWebserver.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/DESeq2_gene.tar.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/DESeq2_gene.tar.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/cleanme.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/cleanme.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/DESeq2_trans.tar.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/DESeq2_trans.tar.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.cds.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.cds.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_genes.counts.matrix.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_genes.counts.matrix.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_trans.counts.matrix.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_trans.counts.matrix.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.gene_to_trans_map.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.gene_to_trans_map.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_trans.TMM.EXPR.matrix.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_trans.TMM.EXPR.matrix.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_genes.TMM.EXPR.matrix.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity_genes.TMM.EXPR.matrix.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/hmmerdb/Pfam-A.hmm to resources/DBs/hmmerdb/Pfam-A.hmm
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.gff3.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.gff3.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.bed.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.bed.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/samples.txt.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/samples.txt.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/resources/eggnog/3.0/COG_KOG_NOG.funccat.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/resources/eggnog/3.0/COG_KOG_NOG.funccat.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/signalp.out.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/signalp.out.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/tmhmm.out.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/tmhmm.out.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/swissprot.blastx.outfmt6.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/swissprot.blastx.outfmt6.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.pep.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/Trinity.fasta.transdecoder.pep.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/runMe.sh to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/runMe.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/TrinotatePFAM.out.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/TrinotatePFAM.out.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/Trinotate_get_feature_name_encoding_attributes.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/Trinotate_get_feature_name_encoding_attributes.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/count_table_fields.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/count_table_fields.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/Trinotate_GTF_or_GFF3_annot_prep.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/Trinotate_GTF_or_GFF3_annot_prep.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/extract_GO_assignments_from_Trinotate_xls.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/extract_GO_assignments_from_Trinotate_xls.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/Trinotate_report_writer.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/Trinotate_report_writer.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/annotation_importer/import_Trinotate_xls_as_annot.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/annotation_importer/import_Trinotate_xls_as_annot.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/prep_nuc_prot_set_for_trinotate_loading.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/prep_nuc_prot_set_for_trinotate_loading.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/auto_Trinotate.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/util/auto_Trinotate.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/generate_Trinotate_report.txt to resources/DBs/sqlite_db/Trinotate_build_scripts/util/generate_Trinotate_report.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/swissprot.blastp.outfmt6.gz to resources/DBs/sqlite_db/Trinotate_build_scripts/sample_data/data/swissprot.blastp.outfmt6.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/gene_ontology/__deprecated/notes to resources/DBs/sqlite_db/Trinotate_build_scripts/util/gene_ontology/__deprecated/notes
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/annotation_importer/import_transcript_names.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/annotation_importer/import_transcript_names.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/functional_enrichment_analysis/run_cluster_functional_enrichment_analysis.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/functional_enrichment_analysis/run_cluster_functional_enrichment_analysis.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/gene_ontology/Trinotate_GO_to_SLIM.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/gene_ontology/Trinotate_GO_to_SLIM.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/assign_eggnog_funccats.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/assign_eggnog_funccats.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/trinotate_report_summary.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/trinotate_report_summary.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/extract_GO_for_BiNGO.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/extract_GO_for_BiNGO.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/shrink_db.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/shrink_db.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/gene_ontology/__deprecated/runMe.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/gene_ontology/__deprecated/runMe.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/trinotate_canvasXpress_Rstudio.R to resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/trinotate_canvasXpress_Rstudio.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/rnammer_support/RnammerTranscriptome.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/rnammer_support/RnammerTranscriptome.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/sqlite.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/sqlite.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/create_clusters_tables.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/create_clusters_tables.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/rnammer_support/util/rnammer_supperscaffold_gff_to_indiv_transcripts.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/rnammer_support/util/rnammer_supperscaffold_gff_to_indiv_transcripts.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/rnammer_support/util/superScaffoldGenerator.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/rnammer_support/util/superScaffoldGenerator.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/build_DE_cache_tables.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/build_DE_cache_tables.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/extract_specific_genes_from_all_matrices.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/extract_specific_genes_from_all_matrices.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_DE_results.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_DE_results.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_samples_only.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_samples_only.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/import_transcript_clusters.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/import_transcript_clusters.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/make_cXp_html.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/make_cXp_html.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_expression_matrix.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_expression_matrix.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/import_expression_and_DE_results.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/import_expression_and_DE_results.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/TrinotateSeqLoader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/TrinotateSeqLoader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_samples_n_expression_matrix.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/deprecated/import_samples_n_expression_matrix.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_SIGNALP_loader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_SIGNALP_loader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/import_transcript_annotations.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/transcript_expression/import_transcript_annotations.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_RNAMMER_loader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_RNAMMER_loader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_TMHMM_loader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_TMHMM_loader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_PFAM_loader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_PFAM_loader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/update_transcript_seqs_only.dbi to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/update_transcript_seqs_only.dbi
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_GTF_loader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_GTF_loader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/logo.png to resources/DBs/sqlite_db/Trinotate_build_scripts/util/report_summary/util/logo.png
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/update_seq_n_annotation_fields.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/update_seq_n_annotation_fields.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_BLAST_loader.pl to resources/DBs/sqlite_db/Trinotate_build_scripts/util/trinotateSeqLoader/Trinotate_BLAST_loader.pl
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/sqlite_db/uniprot_sprot.pep to resources/DBs/sqlite_db/uniprot_sprot.pep
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/GO_plots.R to resources/bin/GO_plots.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/TransPi_Report_Ind.Rmd to resources/bin/TransPi_Report_Ind.Rmd
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/addAnnotation.py to resources/bin/addAnnotation.py
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/custom_uniprot_hits.R to resources/bin/custom_uniprot_hits.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/busco_comparison.R to resources/bin/busco_comparison.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/get_busco_val.sh to resources/bin/get_busco_val.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/get_sizes.sh to resources/bin/get_sizes.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/heatmap_busco.R to resources/bin/heatmap_busco.R
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/get_readstats.sh to resources/bin/get_readstats.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/get_readqual.sh to resources/bin/get_readqual.sh
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/len.py to resources/bin/len.py
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/conf/busV4list.txt to resources/conf/busV4list.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/bin/SOS_busco.py to resources/bin/SOS_busco.py
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/conf/test.config to resources/conf/test.config
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/conf/uni_tax.txt to resources/conf/uni_tax.txt
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/DBs/uniprot_db/uniprot_sprot.fasta to resources/DBs/uniprot_db/uniprot_sprot.fasta
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94881_R2.fastq.gz to resources/seq2/SL94881_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94882_R2.fastq.gz to resources/seq2/SL94882_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94883_R2.fastq.gz to resources/seq2/SL94883_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94884_R1.fastq.gz to resources/seq2/SL94884_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94881_R1.fastq.gz to resources/seq2/SL94881_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94883_R1.fastq.gz to resources/seq2/SL94883_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94882_R1.fastq.gz to resources/seq2/SL94882_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94885_R2.fastq.gz to resources/seq2/SL94885_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94886_R1.fastq.gz to resources/seq2/SL94886_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94884_R2.fastq.gz to resources/seq2/SL94884_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94885_R1.fastq.gz to resources/seq2/SL94885_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/SL94886_R2.fastq.gz to resources/seq2/SL94886_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/joined_R2.fastq.gz to resources/seq2/joined_R2.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/trans/Pseudacris_regilla_GAEI01.1.fa to resources/trans/Pseudacris_regilla_GAEI01.1.fa
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/seq2/joined_R1.fastq.gz to resources/seq2/joined_R1.fastq.gz
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/trans/Oncorhynchus_mykiss_GGBN01.1.fa to resources/trans/Oncorhynchus_mykiss_GGBN01.1.fa
# download: s3://nigms-sandbox/nosi-inbremaine-storage/resources/trans/Microcaecilia_dermatophaga_GFOE01.1.fa to resources/trans/Microcaecilia_dermatophaga_GFOE01.1.fa

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <i class="fa fa-hand-paper-o" aria-hidden="true"></i>
#     <b>Note: </b>  File Paths
# </div>
#
# >Consider the following file structure and you are currently in the directory `toDo`:
# >
# > <img src="../images/fileDemo.png" width="1200">
# >
# >- If you were to type `!ls ./`, it would return the contents of your current directory, so it would return `nextWeek`, `Today.txt`, `Tomorrow.txt`, `Yesterday.txt`.
# >     - The `./` path points to your current directory.
# >
# >- If you were to type `!ls ../`, it would return the contents of the directory 1 layer up from your current directory, so it would return `coolPicturesOcean`, `shoppingList`, `toDo`.
# >    - The `../` path points to the directory one layer up from the current directory.
# >    - They can also be stacked so `../../` will take you two layers up.
# >
# >- If you were to type `!ls ./nextWeek/` it would return the contents of the `nextWeek` directory which is one layer down from the current directory, so it would return `manyThings.txt`.
# >
# >**This means that in the second line of the code cell above, the file `TransPi.nf` will be copied from the Google Cloud Storage bucket to the current directory.**

# %% [markdown]
# **Step 7:** Make the contents of `./TransPi/bin` executable.

# %%
! chmod -R +x ./TransPi/bin

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <i class="fa fa-hand-paper-o" aria-hidden="true"></i>
#     <b>Note: </b>  chmod
# </div>
#
# >The `chmod` command is responsible for granting access to files and directories.
# >
# >Following the `chmod` can be a series of letters and symbols, in the case above `a+rx`.
# >- The first letter can be `u`, `g`, `o`, or `a`.
# >    - `u` stands for owner
# >    - `g` stands for group
# >    - `o` stands for other users
# >    - `a` stands for all
# >
# >
# >- Next can be either a `+` or a `-`.
# >    - `+` grants access
# >    - `-` revokes access
# >
# >
# >- Next the type of permission is indicated (more than one can be there). The options are `r`, `w`, and `x`.
# >    - `r` is read permission
# >    - `w` is write permission
# >    - `x` is execute permission
# >
# >
# >- Finally, the file or directory is designated.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <i class="fa fa-pencil" aria-hidden="true"></i>
#     <b>Checkpoint 1:</b>
# </div>

# %%
from jupyterquiz import display_quiz
display_quiz("../quiz-material/01-cp1.json", shuffle_questions = True)
# Out:
# <div id="YvHGaNgtKmdS" data-shufflequestions="True"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #YvHGaNgtKmdS {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: 140px;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
# </style>

# %% [markdown]
# ## Conclusion
#
# This notebook successfully configured the virtual machine for the MDIBL Transcriptome Assembly Learning Module.  We updated the system, installed necessary software including Java, Mambaforge, and Nextflow, and downloaded the TransPi program and its associated resources from Google Cloud Storage.  The `chmod` command ensured executability of the TransPi scripts.  The VM is now prepared for the next notebook, `Submodule_02_basic_assembly.ipynb`, which will delve into the transcriptome assembly process itself.  Successful completion of this notebook's steps is crucial for the successful execution of subsequent modules.

# %% [markdown]
# ## Clean Up
#
# Remember to proceed to the next notebook [`Submodule_02_basic_assembly.ipynb`](./Submodule_02_basic_assembly.ipynb) or shut down your instance if you are finished.
